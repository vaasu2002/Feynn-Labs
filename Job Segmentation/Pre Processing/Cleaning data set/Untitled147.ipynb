# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/clean004.csv")
df.head()
# Out:
#           Company Name              Location  ...  0 Cloud
# 0          Bosch Group  Bengaluru, Karnataka  ...  0   AWS
# 1   Standard Chartered   Chennai, Tamil Nadu  ...  0   AWS
# 2               Kaplan  Bengaluru, Karnataka  ...  0   AWS
# 3  Corteva Agriscience  Hyderabad, Telangana  ...  0   AWS
# 4   UnitedHealth Group  Bengaluru, Karnataka  ...  0   AWS
#
# [5 rows x 13 columns]

# %%
from wordcloud import wordcloud
from wordcloud import WordCloud, STOPWORDS
def word_cloud(wd_list):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(background_color = 'white',stopwords = stopwords,
                         width = 1600,height = 800,random_state=2,colormap = 'jet',max_words = 100,max_font_size=250).generate(all_words)
    plt.figure(figsize=(12,10))
    plt.axis('off')
    plt.imshow(wordcloud)
word_cloud(df['Description'])

# %%
# Pie chart
labels = df['Location'].unique().head()
sizes = df['Location'].value_counts()
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1, 0, 0)
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2d60d0859bd0> in <module>()
#       8 fig1, ax1 = plt.subplots()
#       9 ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
# ---> 10         shadow=True, startangle=90)
#      11 # Equal aspect ratio ensures that pie is drawn as a circle
#      12 ax1.axis('equal')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
list =

# %%
list
# Out:
# array(['Bengaluru, Karnataka', 'Chennai, Tamil Nadu',
#        'Hyderabad, Telangana', 'India', 'Pune, Maharashtra',
#        'Jaipur, Rajasthan', 'Maharashtra', 'Remote', 'Tamil Nadu',
#        'Remote in Goa', 'Temporarily Remote', 'Gurgaon, Haryana',
#        'Mumbai, Maharashtra', 'India+1 location', 'Surat, Gujarat',
#        'Navi Mumbai, Maharashtra', 'San, Himachal Pradesh',
#        'Remote in India', 'Noida, Uttar Pradesh',
#        'Gurgaon, Haryana+2 locations', 'Delhi, Delhi+1 location',
#        'Kochi, Kerala', 'Mohali, Punjab', 'New Delhi, Delhi',
#        'Hinjawadi, Pune, Maharashtra', 'Remote in Gurgaon, Haryana',
#        'Remote in Bengaluru, Karnataka',
#        'Bellandur, Bengaluru, Karnataka', 'Delhi', 'Ahmedabad, Gujarat',
#        'Temporarily Remote in Bengaluru, Karnataka',
#        'Remote in Pune, Maharashtra', 'Airoli, Navi Mumbai, Maharashtra',
#        'Telangana', 'Karnataka', ' Remote', 'Mysore, Karnataka',
# ...

# %%
df['Location'].unique()
# Out:
# array(['Bengaluru', 'Chennai', 'Hyderabad', 'India', 'Pune', 'Jaipur',
#        'Maharashtra', 'Remote', 'Tamil Nadu', 'Remote in Goa',
#        'Temporarily Remote', 'Gurgaon', 'Mumbai', 'India+1 location',
#        'Surat', 'Navi Mumbai', 'San', 'Remote in India', 'Noida', 'Delhi',
#        'Kochi', 'Mohali', 'New Delhi', 'Hinjawadi', 'Remote in Gurgaon',
#        'Remote in Bengaluru', 'Bellandur', 'Ahmedabad',
#        'Temporarily Remote in Bengaluru', 'Remote in Pune', 'Airoli',
#        'Telangana', 'Karnataka', ' Remote', 'Mysore', 'Nanakramguda',
#        'Sholinganallur', 'Coimbatore', ' Delhi', 'Indore',
#        'Remote in Hyderabad', 'Kanayannur', 'Vadodara', 'Chandigarh',
#        'Agra', 'Kolkata', 'Thiruvananthapuram', 'Bhubaneshwar',
#        'West Bengal', 'Chittoor', 'Remote in Mumbai', ' Punjab',
#        'Kandivali', 'Kanpur', 'Remote in Chennai',
#        'Temporarily Remote in Kolkata', 'Powai', 'Remote in Noida',
# ...

# %%
df['Location'].value_counts()
# Out:
# Bengaluru                             389
# Hyderabad                             104
# Pune                                   83
# Gurgaon                                71
# Mumbai                                 54
#                                      ...
# Nanakramguda, Hyderabad, Telangana      1
# Mohali, Punjab                          1
#  Remote                                 1
# Airoli, Navi Mumbai, Maharashtra        1
# Hadapsar, Pune, Maharashtra             1
# Name: Location, Length: 69, dtype: int64

# %%
for i in range(df.shape[0]):
  if(df['Location'][i] == 'Bengaluru, Karnataka'):
    df['Location'][i] = 'Bengaluru'
  if(df['Location'][i] == 'Hyderabad, Telangana'):
    df['Location'][i] = 'Hyderabad'
  if(df['Location'][i] == 'Pune, Maharashtra'):
    df['Location'][i] = 'Pune'
  if(df['Location'][i] == 'Mumbai, Maharashtra'):
    df['Location'][i] = 'Mumbai'
  if(df['Location'][i] == 'Gurgaon, Haryana'):
    df['Location'][i] = 'Gurgaon'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.to_csv("final_dataset02.csv")

# %%
df = pd.read_csv("/content/final_dataset02.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... Visualization Tool Cloud
# 0           0             0  ...                  0   AWS
# 1           1             1  ...                  0   AWS
# 2           2             2  ...                  0   AWS
# 3           3             3  ...                  0   AWS
# 4           4             4  ...                  0   AWS
#
# [5 rows x 15 columns]

# %%
df.Location.apply(pd.Series).stack().str.strip().value_counts()[:9].plot.pie(figsize=(12,10),startangle=50,autopct='%1.1f%%',fontsize=15)
plt.title("Location wise AI job segmentation",fontsize=30)

centre_circle = plt.Circle((0,0),0.72,color='white',fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')
plt.show()

# %%
for i in range(df.shape[0]):
  if(df['Location'][i] in x):
    df['Location'][i] = 'Remote'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x = ['']

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
 
 
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
 
data = x
 
 
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0,0.2,0.1,0.0,0.2)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
 
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
 
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
# Adding legend
ax.legend(wedges, cars,
          title ="Cars",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
plt.show()

# %%
x = df['Location'].value_counts().head(10)

# %%
x
# Out:
# Bengaluru             392
# Hyderabad             106
# Remote                 84
# Pune                   84
# Gurgaon                72
# Mumbai                 54
# Chennai                40
# Noida                  24
# Delhi                   9
# Thiruvananthapuram      8
# Name: Location, dtype: int64

# %%
df['Location'].value_counts(ascending=False).head(10)
# Out:
# Bengaluru             392
# Hyderabad             106
# Remote                 84
# Pune                   84
# Gurgaon                72
# Mumbai                 54
# Chennai                40
# Noida                  24
# Delhi                   9
# Thiruvananthapuram      8
# Name: Location, dtype: int64

# %%
x =Bengaluru             392
Hyderabad             106
Remote                 84
Pune                   84
Gurgaon                72
Mumbai                 54
Chennai                40
Noida                  24
Delhi                   9
Thiruvananthapuram      8
# Out:
# array(['Bengaluru', 'Chennai', 'Hyderabad', 'Remote', 'Pune', 'Jaipur',
#        'Maharashtra', 'Tamil Nadu', 'Remote in Goa', 'Gurgaon', 'Mumbai',
#        'India+1 location', 'Surat', 'Navi Mumbai', 'San', 'Noida',
#        'Delhi', 'Kochi', 'Mohali', 'New Delhi', 'Hinjawadi',
#        'Remote in Gurgaon', 'Remote in Bengaluru', 'Bellandur',
#        'Ahmedabad', 'Temporarily Remote in Bengaluru', 'Airoli',
#        'Telangana', 'Karnataka', ' Remote', 'Mysore', 'Nanakramguda',
#        'Sholinganallur', 'Coimbatore', ' Delhi', 'Indore',
#        'Remote in Hyderabad', 'Kanayannur', 'Vadodara', 'Chandigarh',
#        'Agra', 'Kolkata', 'Thiruvananthapuram', 'Bhubaneshwar',
#        'West Bengal', 'Chittoor', 'Remote in Mumbai', ' Punjab',
#        'Kandivali', 'Kanpur', 'Powai'], dtype=object)

# %%
df["JOB"].value_counts()[:8].plot.bar(figsize=(13,9),fontsize=10,color="r")
plt.title("AI job Roles",fontsize=50)
plt.ylabel("Jobs listed",fontsize=20,rotation=90)
plt.xlabel("Job Roles",fontsize=20)
plt.set_xticklabels(x_labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-2222fba1e46e> in <module>()
#       3 plt.ylabel("Jobs listed",fontsize=20,rotation=90)
#       4 plt.xlabel("Job Roles",fontsize=20)
# ----> 5 plt.set_xticklabels(x_labels)
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xticklabels'

# %%
import seaborn as sns

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... Visualization Tool Cloud
# 0           0             0  ...                  0   AWS
# 1           1             1  ...                  0   AWS
# 2           2             2  ...                  0   AWS
# 3           3             3  ...                  0   AWS
# 4           4             4  ...                  0   AWS
#
# [5 rows x 15 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x='JOB',hue='Location',data=df,palette='RdBu_r')

# %%
df['Company Name'].apply(pd.Series).stack().str.strip().value_counts()[:10].plot.pie(figsize=(12,10),startangle=50,autopct='%1.1f%%',fontsize=15)
plt.title("Companies with most job offer",fontsize=20)

centre_circle = plt.Circle((0,0),0.72,color='white',fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')
plt.show()

# %%
sns.set_style('darkgrid')
sns.countplot(x='Cloud',data=df)

# %%
sns.set_style('darkgrid')
sns.countplot(x='Python',data=df)

# %%
sns.set_style('darkgrid')
sns.countplot(x='R language',data=df)

# %%
sns.set_style('darkgrid')
sns.countplot(x='SQL',data=df)

# %%
sns.set_style('darkgrid')
sns.countplot(x='LinuxL',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-ec06023a0b5a> in <module>()
#       1 sns.set_style('darkgrid')
# ----> 2 sns.countplot(x='LinuxL',data=df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='JOB',hue='Visualization Tool',data=df,palette='RdBu_r')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... Visualization Tool Cloud
# 0           0             0  ...                  0   AWS
# 1           1             1  ...                  0   AWS
# 2           2             2  ...                  0   AWS
# 3           3             3  ...                  0   AWS
# 4           4             4  ...                  0   AWS
#
# [5 rows x 15 columns]

# %%
Data_scientists=df.groupby(by="State").size().reset_index(name="count").sort_values(by="count",ascending=False)
plt.figure(figsize=(10,7))
plt.yticks(size=20)
sns.barplot(y="State",x="count",data=Data_scientists.head(20))
plt.title("AI Jobs",size=20)
plt.xticks(size=15)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-f12ac7b839a2> in <module>()
#       1
# ----> 2 Data_scientists=df.groupby(by="State").size(9).reset_index(name="count").sort_values(by="count",ascending=False)
#       3 plt.figure(figsize=(10,7))
#       4 plt.yticks(size=20)
#       5 sns.barplot(y="State",x="count",data=Data_scientists.head(20))
#
# TypeError: size() takes 1 positional argument but 2 were given

# %%
x = df['Location'].head(20).unique()

# %%
x
# Out:
# array(['Bengaluru', 'Chennai', 'Hyderabad', 'Remote', 'Pune', 'Jaipur',
#        'Maharashtra'], dtype=object)

# %%
l = []
for i in range(df.shape[0]):
  if(df['Location'][i] in x):
    l.append(df['Location'][i])
  else:
    l.append(np.NaN)

# %%
l
# Out:
# ['Bengaluru',
#  'Chennai',
#  'Bengaluru',
#  'Hyderabad',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Remote',
#  'Remote',
#  'Pune',
#  'Jaipur',
#  'Pune',
#  'Bengaluru',
#  'Chennai',
#  'Bengaluru',
#  'Maharashtra',
#  'Remote',
#  'Bengaluru',
#  'Bengaluru',
#  nan,
#  nan,
#  'Hyderabad',
#  'Remote',
#  nan,
#  'Bengaluru',
#  'Remote',
#  'Remote',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  nan,
#  nan,
#  'Hyderabad',
#  'Bengaluru',
#  'Remote',
#  'Bengaluru',
#  'Hyderabad',
#  'Bengaluru',
#  nan,
#  'Bengaluru',
#  'Remote',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  nan,
#  'Pune',
#  'Remote',
#  'Bengaluru',
#  nan,
#  nan,
#  'Hyderabad',
#  'Bengaluru',
#  'Remote',
#  nan,
#  'Pune',
#  'Bengaluru',
#  'Bengaluru',
#  nan,
#  'Pune',
#  'Pune',
#  nan,
#  'Pune',
#  'Pune',
#  'Bengaluru',
#  'Bengaluru',
#  'Remote',
#  nan,
#  'Bengaluru',
#  nan,
#  'Remote',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
df2 = pd.DataFrame(l,df['Linux'])

# %%
df2
# Out:
#             City
# Linux
# 0      Bengaluru
# 1        Chennai
# 0      Bengaluru
# 1      Hyderabad
# 0      Bengaluru
# ...          ...
# 0            NaN
# 0      Hyderabad
# 0            NaN
# 0            NaN
# 1      Bengaluru
#
# [985 rows x 1 columns]

# %%
df2 = df2.rename(columns={0: 'City'})

# %%
sns.set_style('whitegrid')
sns.countplot(x='Linux',hue='City',data=df2,palette='RdBu_r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-15c3f9b7c881> in <module>()
#       1 sns.set_style('whitegrid')
# ----> 2 sns.countplot(x='Linux',hue='City',data=df2,palette='RdBu_r')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# ...

# %%
df00 = pd.read_csv("https://raw.githubusercontent.com/Kareppa321/ML-JOBS-SEGMENTATION/main/DataScience_jobs.csv")
df00.head()
# Out:
#    Unnamed: 0  ...                                             skills
# 0           0  ...  Data Science\nArtificial Intelligence\ntrainin...
# 1           1  ...  Data Science\nMultivariate Analysis\nFactor An...
# 2           2  ...  Azure\ntimeseries forecasting\nMachine Learnin...
# 3           3  ...  Data Science\nR\nC\nData Scientist\nStatistica...
# 4           4  ...  R\nA/B Testing\nData Manipulation\nMachine Lea...
#
# [5 rows x 6 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... Visualization Tool Cloud
# 0           0             0  ...                  0   AWS
# 1           1             1  ...                  0   AWS
# 2           2             2  ...                  0   AWS
# 3           3             3  ...                  0   AWS
# 4           4             4  ...                  0   AWS
#
# [5 rows x 15 columns]

# %%
A = list(df00['experience'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-5300104249bd> in <module>()
# ----> 1 A = list(df00['experience'])
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
B = list(df00['skills'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-70e80ebfcc03> in <module>()
# ----> 1 B = list(df00['skills'])
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df00.shape[0]
# Out:
# 1282

# %%
df.shape[0]
# Out:
# 985

# %%
df00.shape[0]
# Out:
# 1282

# %%
mylist = ["apple", "banana", "cherry"]
random.shuffle(mylist)

print(mylist)

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
B
# Out:
# 0       Data Science\nArtificial Intelligence\ntrainin...
# 1       Data Science\nMultivariate Analysis\nFactor An...
# 2       Azure\ntimeseries forecasting\nMachine Learnin...
# 3       Data Science\nR\nC\nData Scientist\nStatistica...
# 4       R\nA/B Testing\nData Manipulation\nMachine Lea...
#                               ...
# 1277    Computer vision\ndeep learning\nC++\nImage pro...
# 1278    Product quality\nOperational excellence\nPharm...
# 1279    Product quality\nOperational excellence\nPharm...
# 1280    Data Science\nPyspark\nR\nSAS SQL\nHive\nBig D...
# 1281    Web services\nspark\nR Programming\nDatabase\n...
# Name: skills, Length: 1282, dtype: object

# %%
A
# Out:
# 0       2-7 Yrs
# 1       5-7 Yrs
# 2       3-5 Yrs
# 3       2-5 Yrs
# 4       3-8 Yrs
#          ...
# 1277    1-3 Yrs
# 1278    3-7 Yrs
# 1279    2-5 Yrs
# 1280    3-5 Yrs
# 1281    2-6 Yrs
# Name: experience, Length: 1282, dtype: object

# %%
df222 = pd.DataFrame(B)

# %%
df222
# Out:
#                                                  skills
# 0     Data Science\nArtificial Intelligence\ntrainin...
# 1     Data Science\nMultivariate Analysis\nFactor An...
# 2     Azure\ntimeseries forecasting\nMachine Learnin...
# 3     Data Science\nR\nC\nData Scientist\nStatistica...
# 4     R\nA/B Testing\nData Manipulation\nMachine Lea...
# ...                                                 ...
# 1277  Computer vision\ndeep learning\nC++\nImage pro...
# 1278  Product quality\nOperational excellence\nPharm...
# 1279  Product quality\nOperational excellence\nPharm...
# 1280  Data Science\nPyspark\nR\nSAS SQL\nHive\nBig D...
# 1281  Web services\nspark\nR Programming\nDatabase\n...
#
# [1282 rows x 1 columns]

# %%
df222.to_csv("skill.csv")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns
import plotly.express as pxp
import plotly.graph_objs as gph
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from numpy import where
from numpy import unique
from sklearn.datasets import make_classification
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering

# %%
train_data, _ = make_classification(n_samples=1000,
                                       n_features=2,
                                       n_informative=2,
                                       n_redundant=0,
                                       n_clusters_per_class=1,
                                       random_state=4)

agg_mdl = AgglomerativeClustering(n_clusters=4)

# each data point assigned to cluster
agg_result = agg_mdl.fit_predict(train_data)

# Obtain all clusters which are unique
agg_clusters = unique(agg_result)

# plot clusters
for agg_cluster in agg_clusters:
    # fetch data point that fall in this clstr
    index = where(agg_result == agg_cluster)

    plot.scatter(train_data[index, 0], train_data[index,1])
    
# Agglomerative hierarchy plot
plot.show()

# %%
#init data
train_data, _ = make_classification(n_samples=900,
                                       n_features=4,
                                       n_informative=2,
                                       n_redundant=0,
                                       n_clusters_per_class=1,
                                       random_state=4)

gaussian_mdl = GaussianMixture(n_components=2)

# model training
gaussian_mdl.fit(train_data)

# data points assigned to a cluster
gaussian_res = gaussian_mdl.fit_predict(train_data)

# get clusters which are unique
gaussian_clstr = unique(gaussian_res)

# Plot 
for gaussian_cluser in gaussian_clstr:
    
    index = where(gaussian_res == gaussian_cluser)
    # plot
    plot.scatter(train_data[index, 0], train_data[index, 1])
    
# show plot
plot.show()

# %%
x_input = data.loc[:, ['Salary', 'Experience']].values


wcss = []
for k in range(1, 12):
    k_means = KMeans(n_clusters=k, init='k-means++')
    k_means.fit(x_input)
    wcss.append(k_means.inertia_)
    
plot.figure(figsize=(15,8))

plot.plot(range(1, 12), wcss, linewidth=2, marker='8')
plot.title('Elbow method\n', fontsize=18)
plot.xlabel('no of clusters')
plot.ylabel('WCSS')
plot.show()
